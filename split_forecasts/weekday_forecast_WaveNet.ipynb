# %%
# !nvidia-smi
# Out:
# Tue May 26 18:01:43 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive/Projects/Anomaly_Detection_Time_Series
# Out:
# /content/drive/My Drive/Projects/Anomaly_Detection_Time_Series

# %%
import os
import json
import numpy as np
import pandas as po
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

# %%
import tensorflow as tf

# %%
class Args:
  def __init__(self):
    self.val_start = 12*24*150
    self.test_start = 12*24*200
    self.train_seq_len = 12*24*10
    self.val_seq_len = 12*24
    
    self.conv_num_channels_1 = 64
    self.conv_num_channels_2 = 128
    self.kernel_size = 12
    self.dilation_rates = [2**i for i in range(8)]
    self.batch_size = 128
    self.num_epochs = 25

    self.save_folder = 'weekday_forecast_WaveNet'

# %%
args = Args()

# %%
os.makedirs('forecasts/', exist_ok=True)
os.makedirs('forecasts/' + args.save_folder, exist_ok=True)

# %%
df = po.read_csv('data/2017_energy_5min_noTransform.csv')

# %%
scaler = MinMaxScaler()
df['W'] = scaler.fit_transform(df)

# %%
weekday_power_series = []
weekend_power_series = []
for i in tqdm(range(0, len(df)-7, 7*288)):
  weekday_power_series += df['W'][i:i+5*288].tolist()
  weekend_power_series += df['W'][i+5*288:i+7*288].tolist()
# Out:
# 100%|██████████| 50/50 [00:00<00:00, 2280.45it/s]

# %%
train_arr = weekday_power_series[: args.val_start]
val_arr = weekday_power_series[args.val_start: args.test_start]
test_arr = weekday_power_series[args.test_start:]

# %%
def make_windows(data, train_seq_len = args.train_seq_len, val_seq_len = args.val_seq_len):
    X = []
    y = []

    for i in tqdm(range(train_seq_len, len(data) - val_seq_len + 1)):    
        X.append(data[i - train_seq_len: i])
        y.append(data[i: i + val_seq_len])

    X = np.array(X).squeeze().reshape(-1, train_seq_len, 1)
    y = np.array(y).squeeze()

    return X, y

# %%
X_train, y_train = make_windows(train_arr)
X_val, y_val = make_windows(val_arr)
X_test, y_test = make_windows(test_arr)
# Out:
# 100%|██████████| 40033/40033 [00:02<00:00, 15698.36it/s]
# 100%|██████████| 11233/11233 [00:00<00:00, 24091.48it/s]
# 100%|██████████| 11233/11233 [00:00<00:00, 27756.59it/s]

# %%
history_seq = tf.keras.layers.Input(shape=(args.train_seq_len, 1))
x = history_seq

skips = []
for dilation_rate in args.dilation_rates:
    x = tf.keras.layers.Conv1D(args.conv_num_channels_1, 1, padding='same', activation='relu')(x) 
    
    # filter convolution
    x_f = tf.keras.layers.Conv1D(filters = args.conv_num_channels_2,
                 kernel_size = args.kernel_size, 
                 padding='causal',
                 dilation_rate = dilation_rate)(x)
    
    # gating convolution
    x_g = tf.keras.layers.Conv1D(filters = args.conv_num_channels_2,
                 kernel_size = args.kernel_size, 
                 padding='causal',
                 dilation_rate = dilation_rate)(x)
    
    # multiply filter and gating branches
    z = tf.keras.layers.Multiply()([tf.keras.layers.Activation('tanh')(x_f),
                    tf.keras.layers.Activation('sigmoid')(x_g)])
    
    # postprocessing - equivalent to time-distributed dense
    z = tf.keras.layers.Conv1D(args.conv_num_channels_1, 1, padding='same', activation='relu')(z)
    
    # residual connection
    x = tf.keras.layers.Add()([x, z])    
    
    # collect skip connections
    skips.append(z)

# add all skip connection outputs 
out = tf.keras.layers.Activation('relu')(tf.keras.layers.Add()(skips))

# final time-distributed dense layers 
out = tf.keras.layers.Conv1D(args.conv_num_channels_1, 1, padding='same')(out)
out = tf.keras.layers.Activation('relu')(out)
out = tf.keras.layers.Dropout(.2)(out)
out = tf.keras.layers.Conv1D(1, 1, padding='same')(out)

out = tf.keras.layers.Flatten()(out)
out = tf.keras.layers.Dense(args.val_seq_len)(out)

model = tf.keras.Model(history_seq, out)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 2880, 1)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 2880, 64)     128         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 2880, 128)    98432       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 2880, 128)    98432       conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 2880, 128)    0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 2880, 128)    0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 2880, 128)    0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 2880, 64)     8256        multiply[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 2880, 64)     0           conv1d[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 2880, 64)     4160        add[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 2880, 128)    98432       conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 2880, 128)    98432       conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 2880, 128)    0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 2880, 128)    0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 2880, 128)    0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 2880, 64)     8256        multiply_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 2880, 64)     0           conv1d_4[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 2880, 64)     4160        add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 2880, 128)    98432       conv1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 2880, 128)    98432       conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 2880, 128)    0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 2880, 128)    0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 2880, 128)    0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 2880, 64)     8256        multiply_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 2880, 64)     0           conv1d_8[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 2880, 64)     4160        add_2[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 2880, 128)    98432       conv1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 2880, 128)    98432       conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 2880, 128)    0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 2880, 128)    0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 2880, 128)    0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 2880, 64)     8256        multiply_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 2880, 64)     0           conv1d_12[0][0]
#                                                                  conv1d_15[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 2880, 64)     4160        add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 2880, 128)    98432       conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 2880, 128)    98432       conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2880, 128)    0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2880, 128)    0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 2880, 128)    0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 2880, 64)     8256        multiply_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 2880, 64)     0           conv1d_16[0][0]
#                                                                  conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 2880, 64)     4160        add_4[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 2880, 128)    98432       conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 2880, 128)    98432       conv1d_20[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 2880, 128)    0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 2880, 128)    0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 2880, 128)    0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 2880, 64)     8256        multiply_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 2880, 64)     0           conv1d_20[0][0]
#                                                                  conv1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 2880, 64)     4160        add_5[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 2880, 128)    98432       conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 2880, 128)    98432       conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 2880, 128)    0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 2880, 128)    0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 2880, 128)    0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 2880, 64)     8256        multiply_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 2880, 64)     0           conv1d_24[0][0]
#                                                                  conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 2880, 64)     4160        add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 2880, 128)    98432       conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 2880, 128)    98432       conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 2880, 128)    0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 2880, 128)    0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 2880, 128)    0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 2880, 64)     8256        multiply_7[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 2880, 64)     0           conv1d_3[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_11[0][0]
#                                                                  conv1d_15[0][0]
#                                                                  conv1d_19[0][0]
#                                                                  conv1d_23[0][0]
#                                                                  conv1d_27[0][0]
#                                                                  conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 2880, 64)     0           add_8[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 2880, 64)     4160        activation_16[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 2880, 64)     0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 2880, 64)     0           activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 2880, 1)      65          dropout[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 2880)         0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 288)          829728      flatten[0][0]
# ==================================================================================================
# Total params: 2,504,161
# Trainable params: 2,504,161
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
sgd = tf.keras.optimizers.SGD(lr=0.1, decay=1e-8, momentum=0.9, nesterov=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.001, patience=2)
loss_funk = tf.keras.losses.MeanSquaredError(reduction='sum_over_batch_size')

# %%
model.compile(optimizer = sgd, loss = loss_funk)

# %%
history = model.fit(X_train, y_train, batch_size = args.batch_size, epochs = args.num_epochs, validation_data = (X_val, y_val), callbacks=[earlystop], verbose=1)
# Out:
# Epoch 1/25
# 313/313 [==============================] - 278s 889ms/step - loss: 0.0250 - val_loss: 0.0106
# Epoch 2/25
# 313/313 [==============================] - 277s 884ms/step - loss: 0.0101 - val_loss: 0.0094
# Epoch 3/25
# 313/313 [==============================] - 276s 883ms/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 4/25
# 313/313 [==============================] - 276s 883ms/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 5/25
# 313/313 [==============================] - 276s 882ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 6/25
# 313/313 [==============================] - 276s 883ms/step - loss: 0.0078 - val_loss: 0.0083
# Epoch 7/25
# 313/313 [==============================] - 276s 883ms/step - loss: 0.0076 - val_loss: 0.0086
# Epoch 8/25
# 313/313 [==============================] - 276s 882ms/step - loss: 0.0073 - val_loss: 0.0083
# Epoch 9/25
# 313/313 [==============================] - 276s 883ms/step - loss: 0.0071 - val_loss: 0.0079

# %%
best_epoch = np.argmin(np.array(history.history['val_loss']))+1
model.save_weights('forecasts/' + args.save_folder + '/model_{:02d}.h5'.format(best_epoch))
model.load_weights('forecasts/' + args.save_folder + '/model_{:02d}.h5'.format(best_epoch))
best_epoch
# Out:
# 9

# %%
y_pred = model.predict(X_test)

# %%
plot_df = po.DataFrame.from_dict({'train_loss':history.history['loss'], 'val_loss':history.history['val_loss']})
plot_df.plot(logy=True, figsize=(10,10), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.savefig('forecasts/' + args.save_folder + '/train_val_loss.png')
plt.show()

# %%
plt.plot(y_test[0], color = 'blue')
plt.plot(y_pred[0], color = 'red')
plt.savefig('forecasts/' + args.save_folder + '/test_weekend_pred.png')

# %%
plt.plot(y_test[12*24*2], color = 'blue')
plt.plot(y_pred[12*24*2], color = 'red')
plt.savefig('forecasts/'  + args.save_folder + '/test_weekday_pred.png')

# %%
forecasts = []
actuals = []
forecasts_n = []
actuals_n = []
for i in tqdm(range(y_pred.shape[0]//288)): ## we have forecasts for these many complete day
  forecasts += (scaler.inverse_transform(y_pred[12*24*i].reshape(-1, 1)).reshape(-1)).tolist()
  actuals += (scaler.inverse_transform(y_test[12*24*i].reshape(-1, 1)).reshape(-1)).tolist()
  forecasts_n += y_pred[12*24*i].tolist()
  actuals_n += y_test[12*24*i].tolist()
# Out:
# 100%|██████████| 39/39 [00:00<00:00, 4248.11it/s]

# %%
df_pred = po.DataFrame()
df_pred['Predictions'] = forecasts
df_pred['Actual Values'] = actuals

# %%
df_pred.to_csv('forecasts/' + args.save_folder + '/full_results.csv', index = False)

# %%
df_pred_n = po.DataFrame()
df_pred_n['Predictions'] = forecasts_n
df_pred_n['Actual Values'] = actuals_n

# %%
df_pred_n.to_csv('forecasts/' + args.save_folder + '/full_results_normalized.csv', index = False)

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Days', size = 20)
plt.ylabel('Energy Comsumption (kWh)', size = 20)
plt.xticks(ticks = list(range(0, len(forecasts) + 1, 288)), labels = list(range(0, int(len(forecasts)/288 + 1))), size = 10)
plt.yticks(size = 10)
plt.plot(actuals, color = 'blue')
plt.plot(forecasts, color = 'red')
plt.legend(['Actual Value', 'Prediction'])
plt.savefig('forecasts/' + args.save_folder + '/forecast.png')

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Days', size = 20)
plt.ylabel('Energy Comsumption (kWh)', size = 20)
plt.xticks(ticks = list(range(0, len(forecasts) + 1, 288)), labels = list(range(0, int(len(forecasts)/288 + 1))), size = 10)
plt.yticks(size = 10)
plt.plot(actuals_n, color = 'blue')
plt.plot(forecasts_n, color = 'red')
plt.legend(['Actual Value', 'Prediction'])
plt.savefig('forecasts/' + args.save_folder + '/forecast_normalized.png')

# %%
if not os.path.exists('forecasts/results.csv'):
  results = po.DataFrame(columns = ['model', 'MAE', 'MSE', 'R2'])  
else:
  results = po.read_csv('forecasts/results.csv')

# %%
errors = {'model': args.save_folder,
          'MAE': mean_absolute_error(y_true=y_test, y_pred=y_pred),
          'MAPE': mean_absolute_error(y_true=y_test, y_pred=y_pred)*100,
          'MSE': mean_squared_error(y_true=y_test, y_pred=y_pred),
          'RMSE': mean_squared_error(y_true=y_test, y_pred=y_pred, squared=False),
          'R2': r2_score(y_true=y_test, y_pred=y_pred)          
          }
errors = po.Series(errors)
results = results.append(errors, ignore_index=True)

# %%
results
# Out:
#                            model       MAE  ...      MAPE      RMSE
# 0                       CNN_LSTM  0.048751  ...  4.875098  0.063956
# 1                    Dilated_CNN  0.049959  ...  4.995887  0.062528
# 2                       convLSTM  0.045311  ...  4.531112  0.058987
# 3   weekend_forecast_Dilated_CNN  0.044546  ...  4.454638  0.053893
# 4      weekend_forecast_CNN_LSTM  0.040486  ...  4.048602  0.050856
# 5     weekend_forecast_conv_LSTM  0.038764  ...  3.876431  0.049156
# 6       weekend_forecast_WaveNet  0.047001  ...  4.700087  0.056060
# 7                        WaveNet  0.038622  ...  3.862250  0.052177
# 8   weekday_forecast_Dilated_CNN  0.057209  ...  5.720929  0.072542
# 9      weekday_forecast_CNN_LSTM  0.039897  ...  3.989721  0.052985
# 10    weekday_forecast_conv_LSTM  0.039710  ...  3.971010  0.052723
# 11      weekday_forecast_WaveNet  0.046508  ...  4.650779  0.060408
#
# [12 rows x 6 columns]

# %%
results.to_csv('forecasts/results.csv', index=False)
