# %%
import random
import argparse
import numpy as np
import pandas as po
from tqdm import tqdm
import tensorflow as tf
import matplotlib.pyplot as plt
from models.nbeats import NBeatsNet
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

# %%
# set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# %%
df = po.read_csv('final_data/univariate.csv')
df
# Out:
#          consumption
# 0      126661.288667
# 1      125975.630600
# 2      131628.821400
# 3      133741.109667
# 4      149806.386667
# ...              ...
# 99643  103932.504002
# 99644  102064.379714
# 99645  100378.796042
# 99646   98593.460339
# 99647   97365.874939
#
# [99648 rows x 1 columns]

# %%
scaler = MinMaxScaler()
df = po.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
train_df = df[:int(0.6*len(df))]
val_df = df[int(0.6*len(df)): int(0.8*len(df))]
test_df = df[int(0.8*len(df)):]

# %%
len(train_df), len(val_df), len(test_df)
# Out:
# (59788, 19930, 19930)

# %%
plt.figure(figsize=(20, 10))
plt.plot(train_df['consumption'], color='blue')
plt.plot(val_df['consumption'], color='orange')
plt.plot(test_df['consumption'], color='red')
plt.legend(['Train Sequence', 'Validation Sequence', 'Test Sequence'])

# %%
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# %%
lookback=4*24*14
horizon=4*24*1

# %%
def make_windows(data, target_col='consumption', lookback=4*24*14, horizon=4*24*1):
    
    X = np.zeros((len(data)-lookback - horizon + 1, lookback, len(data.columns)))
    y = np.zeros((len(data)-lookback - horizon + 1, horizon, 1))

    for i in tqdm(range(lookback, len(data) - horizon + 1)):  
        X[i-lookback, :, :] = data.iloc[i - lookback: i].values
        y[i-lookback, :, :] = data.iloc[i: i + horizon][target_col].values.reshape(-1, 1)

    return X, y

# %%
X_train, y_train = make_windows(train_df)
# Out:
# 100%|██████████| 58349/58349 [00:09<00:00, 6243.06it/s]

# %%
X_val, y_val = make_windows(val_df)
# Out:
# 100%|██████████| 18491/18491 [00:02<00:00, 6191.08it/s]

# %%
X_test, y_test = make_windows(test_df)
# Out:
# 100%|██████████| 18491/18491 [00:03<00:00, 6126.06it/s]

# %%
#sgd = tf.keras.optimizers.SGD(lr=0.1, decay=1e-8, momentum=0.9, nesterov=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=10)
loss_funk = tf.keras.losses.MeanSquaredError(reduction='sum_over_batch_size')

# %%
hidden_dim = 50
theta_1 = 4*24*7
theta_2 = 4*24*7
nb_blocks_per_stack = 20
seasonality = 4*24*7
batch_size = 256
num_epochs = 100

# %%
model = NBeatsNet(input_dim=len(train_df.columns), backcast_length = lookback, forecast_length = horizon,
                  stack_types=(NBeatsNet.GENERIC_BLOCK, NBeatsNet.GENERIC_BLOCK), nb_blocks_per_stack=nb_blocks_per_stack,
                  thetas_dim=(theta_1, theta_2), share_weights_in_stack=True, hidden_layer_units=hidden_dim)
          
model.compile_model(loss='mse', learning_rate=1e-4)
# Out:
# ic/d4[17][0]
#                                                                  0/0/generic/d4[18][0]
#                                                                  0/0/generic/d4[19][0]
# __________________________________________________________________________________________________
# 0/0/generic/forecast (Dense)    (None, 96)           64608       0/0/generic/theta_f[0][0]
#                                                                  0/0/generic/theta_f[1][0]
#                                                                  0/0/generic/theta_f[2][0]
#                                                                  0/0/generic/theta_f[3][0]
#                                                                  0/0/generic/theta_f[4][0]
#                                                                  0/0/generic/theta_f[5][0]
#                                                                  0/0/generic/theta_f[6][0]
#                                                                  0/0/generic/theta_f[7][0]
#                                                                  0/0/generic/theta_f[8][0]
#                                                                  0/0/generic/theta_f[9][0]
#                                                                  0/0/generic/theta_f[10][0]
#                                                                  0/0/generic/theta_f[11][0]
#                                                                  0/0/generic/theta_f[12][0]
#                                                                  0/0/generic/theta_f[13][0]
#                                                                  0/0/generic/theta_f[14][0]
#                                                                  0/0/generic/theta_f[15][0]
#                                                                  0/0/generic/theta_f[16][0]
#                                                                  0/0/generic/theta_f[17][0]
#                                                                  0/0/generic/theta_f[18][0]
#                                                                  0/0/generic/theta_f[19][0]
# __________________________________________________________________________________________________
# add_422 (Add)                   (None, 96)           0           0/0/generic/forecast[0][0]
#                                                                  0/0/generic/forecast[1][0]
# __________________________________________________________________________________________________
# add_423 (Add)                   (None, 96)           0           add_422[0][0]
#                                                                  0/0/generic/forecast[2][0]
# __________________________________________________________________________________________________
# add_424 (Add)                   (None, 96)           0           add_423[0][0]
#                                                                  0/0/generic/forecast[3][0]
# __________________________________________________________________________________________________
# add_425 (Add)                   (None, 96)           0           add_424[0][0]
#                                                                  0/0/generic/forecast[4][0]
# __________________________________________________________________________________________________
# subtract_464 (Subtract)         (None, 1344)         0           subtract_463[0][0]
#                                                                  1/0/generic/backcast[14][0]
# __________________________________________________________________________________________________
# add_426 (Add)                   (None, 96)           0           add_425[0][0]
#                                                                  0/0/generic/forecast[5][0]
# __________________________________________________________________________________________________
# add_427 (Add)                   (None, 96)           0           add_426[0][0]
#                                                                  0/0/generic/forecast[6][0]
# __________________________________________________________________________________________________
# add_428 (Add)                   (None, 96)           0           add_427[0][0]
#                                                                  0/0/generic/forecast[7][0]
# __________________________________________________________________________________________________
# add_429 (Add)                   (None, 96)           0           add_428[0][0]
#                                                                  0/0/generic/forecast[8][0]
# __________________________________________________________________________________________________
# add_430 (Add)                   (None, 96)           0           add_429[0][0]
#                                                                  0/0/generic/forecast[9][0]
# __________________________________________________________________________________________________
# add_431 (Add)                   (None, 96)           0           add_430[0][0]
#                                                                  0/0/generic/forecast[10][0]
# __________________________________________________________________________________________________
# add_432 (Add)                   (None, 96)           0           add_431[0][0]
#                                                                  0/0/generic/forecast[11][0]
# __________________________________________________________________________________________________
# subtract_465 (Subtract)         (None, 1344)         0           subtract_464[0][0]
#                                                                  1/0/generic/backcast[15][0]
# __________________________________________________________________________________________________
# add_433 (Add)                   (None, 96)           0           add_432[0][0]
#                                                                  0/0/generic/forecast[12][0]
# __________________________________________________________________________________________________
# add_434 (Add)                   (None, 96)           0           add_433[0][0]
#                                                                  0/0/generic/forecast[13][0]
# __________________________________________________________________________________________________
# add_435 (Add)                   (None, 96)           0           add_434[0][0]
#                                                                  0/0/generic/forecast[14][0]
# __________________________________________________________________________________________________
# add_436 (Add)                   (None, 96)           0           add_435[0][0]
#                                                                  0/0/generic/forecast[15][0]
# __________________________________________________________________________________________________
# add_437 (Add)                   (None, 96)           0           add_436[0][0]
#                                                                  0/0/generic/forecast[16][0]
# __________________________________________________________________________________________________
# add_438 (Add)                   (None, 96)           0           add_437[0][0]
#                                                                  0/0/generic/forecast[17][0]
# __________________________________________________________________________________________________
# add_439 (Add)                   (None, 96)           0           add_438[0][0]
#                                                                  0/0/generic/forecast[18][0]
# __________________________________________________________________________________________________
# 1/0/generic/theta_f (Dense)     (None, 672)          33600       1/0/generic/d4[0][0]
#                                                                  1/0/generic/d4[1][0]
#                                                                  1/0/generic/d4[2][0]
#                                                                  1/0/generic/d4[3][0]
#                                                                  1/0/generic/d4[4][0]
#                                                                  1/0/generic/d4[5][0]
#                                                                  1/0/generic/d4[6][0]
#                                                                  1/0/generic/d4[7][0]
#                                                                  1/0/generic/d4[8][0]
#                                                                  1/0/generic/d4[9][0]
#                                                                  1/0/generic/d4[10][0]
#                                                                  1/0/generic/d4[11][0]
#                                                                  1/0/generic/d4[12][0]
#                                                                  1/0/generic/d4[13][0]
#                                                                  1/0/generic/d4[14][0]
#                                                                  1/0/generic/d4[15][0]
#                                                                  1/0/generic/d4[16][0]
#                                                                  1/0/generic/d4[17][0]
#                                                                  1/0/generic/d4[18][0]
#                                                                  1/0/generic/d4[19][0]
# __________________________________________________________________________________________________
# subtract_466 (Subtract)         (None, 1344)         0           subtract_465[0][0]
#                                                                  1/0/generic/backcast[16][0]
# __________________________________________________________________________________________________
# add_440 (Add)                   (None, 96)           0           add_439[0][0]
#                                                                  0/0/generic/forecast[19][0]
# __________________________________________________________________________________________________
# 1/0/generic/forecast (Dense)    (None, 96)           64608       1/0/generic/theta_f[0][0]
#                                                                  1/0/generic/theta_f[1][0]
#                                                                  1/0/generic/theta_f[2][0]
#                                                                  1/0/generic/theta_f[3][0]
#                                                                  1/0/generic/theta_f[4][0]
#                                                                  1/0/generic/theta_f[5][0]
#                                                                  1/0/generic/theta_f[6][0]
#                                                                  1/0/generic/theta_f[7][0]
#                                                                  1/0/generic/theta_f[8][0]
#                                                                  1/0/generic/theta_f[9][0]
#                                                                  1/0/generic/theta_f[10][0]
#                                                                  1/0/generic/theta_f[11][0]
#                                                                  1/0/generic/theta_f[12][0]
#                                                                  1/0/generic/theta_f[13][0]
#                                                                  1/0/generic/theta_f[14][0]
#                                                                  1/0/generic/theta_f[15][0]
#                                                                  1/0/generic/theta_f[16][0]
#                                                                  1/0/generic/theta_f[17][0]
#                                                                  1/0/generic/theta_f[18][0]
#                                                                  1/0/generic/theta_f[19][0]
# __________________________________________________________________________________________________
# add_441 (Add)                   (None, 96)           0           add_440[0][0]
#                                                                  1/0/generic/forecast[0][0]
# __________________________________________________________________________________________________
# add_442 (Add)                   (None, 96)           0           add_441[0][0]
#                                                                  1/0/generic/forecast[1][0]
# __________________________________________________________________________________________________
# add_443 (Add)                   (None, 96)           0           add_442[0][0]
#                                                                  1/0/generic/forecast[2][0]
# __________________________________________________________________________________________________
# add_444 (Add)                   (None, 96)           0           add_443[0][0]
#                                                                  1/0/generic/forecast[3][0]
# __________________________________________________________________________________________________
# add_445 (Add)                   (None, 96)           0           add_444[0][0]
#                                                                  1/0/generic/forecast[4][0]
# __________________________________________________________________________________________________
# add_446 (Add)                   (None, 96)           0           add_445[0][0]
#                                                                  1/0/generic/forecast[5][0]
# __________________________________________________________________________________________________
# subtract_467 (Subtract)         (None, 1344)         0           subtract_466[0][0]
#                                                                  1/0/generic/backcast[17][0]
# __________________________________________________________________________________________________
# add_447 (Add)                   (None, 96)           0           add_446[0][0]
#                                                                  1/0/generic/forecast[6][0]
# __________________________________________________________________________________________________
# add_448 (Add)                   (None, 96)           0           add_447[0][0]
#                                                                  1/0/generic/forecast[7][0]
# __________________________________________________________________________________________________
# add_449 (Add)                   (None, 96)           0           add_448[0][0]
#                                                                  1/0/generic/forecast[8][0]
# __________________________________________________________________________________________________
# add_450 (Add)                   (None, 96)           0           add_449[0][0]
#                                                                  1/0/generic/forecast[9][0]
# __________________________________________________________________________________________________
# add_451 (Add)                   (None, 96)           0           add_450[0][0]
#                                                                  1/0/generic/forecast[10][0]
# __________________________________________________________________________________________________
# add_452 (Add)                   (None, 96)           0           add_451[0][0]
#                                                                  1/0/generic/forecast[11][0]
# __________________________________________________________________________________________________
# add_453 (Add)                   (None, 96)           0           add_452[0][0]
#                                                                  1/0/generic/forecast[12][0]
# __________________________________________________________________________________________________
# subtract_468 (Subtract)         (None, 1344)         0           subtract_467[0][0]
#                                                                  1/0/generic/backcast[18][0]
# __________________________________________________________________________________________________
# add_454 (Add)                   (None, 96)           0           add_453[0][0]
#                                                                  1/0/generic/forecast[13][0]
# __________________________________________________________________________________________________
# add_455 (Add)                   (None, 96)           0           add_454[0][0]
#                                                                  1/0/generic/forecast[14][0]
# __________________________________________________________________________________________________
# add_456 (Add)                   (None, 96)           0           add_455[0][0]
#                                                                  1/0/generic/forecast[15][0]
# __________________________________________________________________________________________________
# add_457 (Add)                   (None, 96)           0           add_456[0][0]
#                                                                  1/0/generic/forecast[16][0]
# __________________________________________________________________________________________________
# add_458 (Add)                   (None, 96)           0           add_457[0][0]
#                                                                  1/0/generic/forecast[17][0]
# __________________________________________________________________________________________________
# add_459 (Add)                   (None, 96)           0           add_458[0][0]
#                                                                  1/0/generic/forecast[18][0]
# __________________________________________________________________________________________________
# add_460 (Add)                   (None, 96)           0           add_459[0][0]
#                                                                  1/0/generic/forecast[19][0]
# __________________________________________________________________________________________________
# reshape_8 (Reshape)             (None, 96, 1)        0           add_460[0][0]
# ==================================================================================================
# Total params: 2,222,440
# Trainable params: 2,222,440
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size = batch_size, epochs = num_epochs, validation_data = (X_val, y_val), callbacks=[earlystop], verbose=1)
# Out:
# Epoch 1/100
# 228/228 [==============================] - 10s 46ms/step - loss: 4.1690 - val_loss: 0.0388
# Epoch 2/100
# 228/228 [==============================] - 9s 40ms/step - loss: 0.0334 - val_loss: 0.0199
# Epoch 3/100
# 228/228 [==============================] - 10s 43ms/step - loss: 0.0192 - val_loss: 0.0147
# Epoch 4/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0154 - val_loss: 0.0131
# Epoch 5/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0135 - val_loss: 0.0118
# Epoch 6/100
# 228/228 [==============================] - 10s 42ms/step - loss: 0.0121 - val_loss: 0.0111
# Epoch 7/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0112 - val_loss: 0.0104
# Epoch 8/100
# 228/228 [==============================] - 9s 40ms/step - loss: 0.0106 - val_loss: 0.0100
# Epoch 9/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0101 - val_loss: 0.0097
# Epoch 10/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0098 - val_loss: 0.0095
# Epoch 11/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0095 - val_loss: 0.0093
# Epoch 12/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0092 - val_loss: 0.0091
# Epoch 13/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0090 - val_loss: 0.0092
# Epoch 14/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0089 - val_loss: 0.0089
# Epoch 15/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 16/100
# 228/228 [==============================] - 9s 38ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 17/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 18/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0083 - val_loss: 0.0085
# Epoch 19/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 20/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0081 - val_loss: 0.0084
# Epoch 21/100
# 228/228 [==============================] - 9s 38ms/step - loss: 0.0080 - val_loss: 0.0085
# Epoch 22/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0079 - val_loss: 0.0083
# Epoch 23/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 24/100
# 228/228 [==============================] - 10s 43ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 25/100
# 228/228 [==============================] - 9s 42ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 26/100
# 228/228 [==============================] - 9s 40ms/step - loss: 0.0076 - val_loss: 0.0080
# Epoch 27/100
# 228/228 [==============================] - 10s 42ms/step - loss: 0.0076 - val_loss: 0.0081
# Epoch 28/100
# 228/228 [==============================] - 10s 42ms/step - loss: 0.0075 - val_loss: 0.0080
# Epoch 29/100
# 228/228 [==============================] - 9s 39ms/step - loss: 0.0074 - val_loss: 0.0081
# Epoch 30/100
# 228/228 [==============================] - 9s 38ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 31/100
# 228/228 [==============================] - 9s 40ms/step - loss: 0.0073 - val_loss: 0.0078
# Epoch 32/100
# 228/228 [==============================] - 10s 42ms/step - loss: 0.0072 - val_loss: 0.0079
# Epoch 33/100
# 228/228 [==============================] - 10s 42ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 34/100
# 228/228 [==============================] - 9s 42ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 35/100
# 228/228 [==============================] - 9s 42ms/step - loss: 0.0071 - val_loss: 0.0077
# Epoch 36/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0070 - val_loss: 0.0077
# Epoch 37/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0070 - val_loss: 0.0075
# Epoch 38/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0069 - val_loss: 0.0078
# Epoch 39/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0069 - val_loss: 0.0075
# Epoch 40/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0069 - val_loss: 0.0076
# Epoch 41/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0068 - val_loss: 0.0074
# Epoch 42/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0067 - val_loss: 0.0074
# Epoch 43/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0067 - val_loss: 0.0074
# Epoch 44/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0066 - val_loss: 0.0074
# Epoch 45/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0066 - val_loss: 0.0075
# Epoch 46/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0066 - val_loss: 0.0073
# Epoch 47/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0065 - val_loss: 0.0072
# Epoch 48/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0064 - val_loss: 0.0073
# Epoch 49/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 50/100
# 228/228 [==============================] - 9s 42ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 51/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0063 - val_loss: 0.0074
# Epoch 52/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0062 - val_loss: 0.0072
# Epoch 53/100
# 228/228 [==============================] - 9s 42ms/step - loss: 0.0061 - val_loss: 0.0074
# Epoch 54/100
# 228/228 [==============================] - 9s 42ms/step - loss: 0.0061 - val_loss: 0.0076
# Epoch 55/100
# 228/228 [==============================] - 9s 42ms/step - loss: 0.0060 - val_loss: 0.0073
# Epoch 56/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0059 - val_loss: 0.0071
# Epoch 57/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0059 - val_loss: 0.0071
# Epoch 58/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0059 - val_loss: 0.0072
# Epoch 59/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0058 - val_loss: 0.0073
# Epoch 60/100
# 228/228 [==============================] - 10s 42ms/step - loss: 0.0057 - val_loss: 0.0073
# Epoch 61/100
# 228/228 [==============================] - 10s 42ms/step - loss: 0.0057 - val_loss: 0.0071
# Epoch 62/100
# 228/228 [==============================] - 9s 42ms/step - loss: 0.0056 - val_loss: 0.0072
# Epoch 63/100
# 228/228 [==============================] - 10s 43ms/step - loss: 0.0056 - val_loss: 0.0072
# Epoch 64/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0055 - val_loss: 0.0072
# Epoch 65/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0055 - val_loss: 0.0075
# Epoch 66/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0054 - val_loss: 0.0072
# Epoch 67/100
# 228/228 [==============================] - 9s 41ms/step - loss: 0.0053 - val_loss: 0.0073

# %%
model.save('saved_models/nbeats_univariate.hdf5')

# %%
#model = tf.keras.models.load_model('saved_models/nbeats_univ.hdf5')

# %%
plot_df = po.DataFrame.from_dict({'train_loss':history.history['loss'], 'val_loss':history.history['val_loss']})
plot_df.plot(logy=True, figsize=(10,10), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
#plt.savefig('forecasts/' + args.save_folder + '/train_val_loss.png')
plt.show()

# %%
y_pred = model.predict(X_test)

# %%
y_pred = y_pred.squeeze()
y_test = y_test.squeeze()

# %%
plt.plot(y_test[5251], color = 'blue')
plt.plot(y_pred[5251], color = 'red')
#plt.savefig('forecasts/' + args.save_folder + '/test_1_pred.png')

# %%
forecasts = []
actuals = []
forecasts_n = []
actuals_n = []
for i in tqdm(range(y_pred.shape[0]//288)): ## we have forecasts for these many complete day
  forecasts += (scaler.inverse_transform(y_pred[12*24*i].reshape(-1, 1)).reshape(-1)).tolist()
  actuals += (scaler.inverse_transform(y_test[12*24*i].reshape(-1, 1)).reshape(-1)).tolist()
  forecasts_n += y_pred[12*24*i].tolist()
  actuals_n += y_test[12*24*i].tolist()
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 7267.58it/s]

# %%
df_pred = po.DataFrame()
df_pred['Predictions'] = forecasts
df_pred['Actual Values'] = actuals

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Days', size = 20)
plt.ylabel('Energy Comsumption (kWh)', size = 20)
plt.xticks(ticks = list(range(0, len(forecasts) + 1, 288)), labels = list(range(0, int(len(forecasts)/288 + 1))), size = 10)
plt.yticks(size = 10)
plt.plot(actuals, color = 'blue')
plt.plot(forecasts, color = 'red')
plt.legend(['Actual Value', 'Prediction'])

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Days', size = 20)
plt.ylabel('Energy Comsumption (kWh)', size = 20)
plt.xticks(ticks = list(range(0, len(forecasts) + 1, 288)), labels = list(range(0, int(len(forecasts)/288 + 1))), size = 10)
plt.yticks(size = 10)
plt.plot(actuals_n, color = 'blue')
plt.plot(forecasts_n, color = 'red')
plt.legend(['Actual Value', 'Prediction'])

# %%
results = po.DataFrame(columns = ['MAE', 'MSE', 'R2'])  
errors = {'MAE': mean_absolute_error(y_true=y_test, y_pred=y_pred),
          'MAPE': mean_absolute_error(y_true=y_test, y_pred=y_pred)*100,
          'MSE': mean_squared_error(y_true=y_test, y_pred=y_pred),
          'RMSE': mean_squared_error(y_true=y_test, y_pred=y_pred, squared=False),
          'R2': r2_score(y_true=y_test, y_pred=y_pred)          
          }
errors = po.Series(errors)
results = results.append(errors, ignore_index=True)
results
# Out:
#         MAE      MSE        R2      MAPE      RMSE
# 0  0.067065  0.00958  0.450926  6.706506  0.097877
