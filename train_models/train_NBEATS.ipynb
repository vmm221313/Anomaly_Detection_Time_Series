# %%
# !nvidia-smi
# Out:
# Wed May 27 13:10:02 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd drive/My\ Drive/Projects/Anomaly_Detection_Time_Series
# Out:
# /content/drive/My Drive/Projects/Anomaly_Detection_Time_Series

# %%
import os
import json
import numpy as np
import pandas as po
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

# %%
import tensorflow as tf
from nbeats_model import NBeatsNet
# Out:
# Using TensorFlow backend.

# %%
df = po.read_csv('data/2017_energy_5min_noTransform.csv')

# %%
scaler = MinMaxScaler()
df['W'] = scaler.fit_transform(df)

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
class Args:
  def __init__(self):
    self.val_start = 12*24*250
    self.test_start = 12*24*300
    self.train_seq_len = 12*24*7
    self.val_seq_len = 12*24
    
    self.seasonality = 12*24
    self.batch_size = 512
    self.num_epochs = 100
    self.hidden_dim = 100
    self.theta_1 = 288
    self.theta_2 = 288
    self.nb_blocks_per_stack = 10
    
    self.save_folder = 'NBEATS'

# %%
args = Args()

# %%
os.makedirs('forecasts/', exist_ok=True)
os.makedirs('forecasts/' + args.save_folder, exist_ok=True)

# %%
train_df = df[: args.val_start]
val_df = df[args.val_start: args.test_start]
test_df = df[args.test_start:]

# %%
def make_windows(data, train_seq_len = args.train_seq_len, val_seq_len = args.val_seq_len):
    X = []
    y = []

    for i in tqdm(range(train_seq_len, len(data) - val_seq_len + 1)):    
        X.append(data.values[i - train_seq_len: i].T.tolist())
        y.append(data.values[i: i + val_seq_len].T.tolist())

    X = np.array(X).squeeze().reshape(-1, train_seq_len, 1)
    y = np.array(y).squeeze()

    return X, y

# %%
X_train, y_train = make_windows(train_df)
X_val, y_val = make_windows(val_df)
X_test, y_test = make_windows(test_df)
# Out:
# 100%|██████████| 69697/69697 [00:10<00:00, 6794.76it/s]
# 100%|██████████| 12097/12097 [00:01<00:00, 9283.91it/s]
# 100%|██████████| 12097/12097 [00:01<00:00, 9425.12it/s]

# %%
y_train = y_train.reshape(y_train.shape[0], y_train.shape[1], 1)
y_val = y_val.reshape(y_val.shape[0], y_val.shape[1], 1)
y_test = y_test.reshape(y_test.shape[0], y_test.shape[1], 1)

# %%
sgd = tf.keras.optimizers.SGD(lr=0.1, decay=1e-8, momentum=0.9, nesterov=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0001, patience=4)
loss_funk = tf.keras.losses.MeanSquaredError(reduction='sum_over_batch_size')

# %%
model = NBeatsNet(backcast_length = args.train_seq_len, forecast_length = args.val_seq_len,
                  stack_types=(NBeatsNet.GENERIC_BLOCK, NBeatsNet.GENERIC_BLOCK), nb_blocks_per_stack=args.nb_blocks_per_stack,
                  thetas_dim = (args.theta_1, args.theta_2), share_weights_in_stack = True, hidden_layer_units = args.hidden_dim)
          
model.compile_model(loss='mse', learning_rate = 1e-4)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_variable (InputLayer)     (None, 2016, 1)      0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 2016)         0           input_variable[0][0]
# __________________________________________________________________________________________________
# 0/0/generic/d1 (Dense)          (None, 100)          201700      lambda_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  subtract_2[0][0]
#                                                                  subtract_3[0][0]
#                                                                  subtract_4[0][0]
#                                                                  subtract_5[0][0]
#                                                                  subtract_6[0][0]
#                                                                  subtract_7[0][0]
#                                                                  subtract_8[0][0]
#                                                                  subtract_9[0][0]
# __________________________________________________________________________________________________
# 0/0/generic/d2 (Dense)          (None, 100)          10100       0/0/generic/d1[0][0]
#                                                                  0/0/generic/d1[1][0]
#                                                                  0/0/generic/d1[2][0]
#                                                                  0/0/generic/d1[3][0]
#                                                                  0/0/generic/d1[4][0]
#                                                                  0/0/generic/d1[5][0]
#                                                                  0/0/generic/d1[6][0]
#                                                                  0/0/generic/d1[7][0]
#                                                                  0/0/generic/d1[8][0]
#                                                                  0/0/generic/d1[9][0]
# __________________________________________________________________________________________________
# 0/0/generic/d3 (Dense)          (None, 100)          10100       0/0/generic/d2[0][0]
#                                                                  0/0/generic/d2[1][0]
#                                                                  0/0/generic/d2[2][0]
#                                                                  0/0/generic/d2[3][0]
#                                                                  0/0/generic/d2[4][0]
#                                                                  0/0/generic/d2[5][0]
#                                                                  0/0/generic/d2[6][0]
#                                                                  0/0/generic/d2[7][0]
#                                                                  0/0/generic/d2[8][0]
#                                                                  0/0/generic/d2[9][0]
# __________________________________________________________________________________________________
# 0/0/generic/d4 (Dense)          (None, 100)          10100       0/0/generic/d3[0][0]
#                                                                  0/0/generic/d3[1][0]
#                                                                  0/0/generic/d3[2][0]
#                                                                  0/0/generic/d3[3][0]
#                                                                  0/0/generic/d3[4][0]
#                                                                  0/0/generic/d3[5][0]
#                                                                  0/0/generic/d3[6][0]
#                                                                  0/0/generic/d3[7][0]
#                                                                  0/0/generic/d3[8][0]
#                                                                  0/0/generic/d3[9][0]
# __________________________________________________________________________________________________
# 0/0/generic/theta_b (Dense)     (None, 288)          28800       0/0/generic/d4[0][0]
#                                                                  0/0/generic/d4[1][0]
#                                                                  0/0/generic/d4[2][0]
#                                                                  0/0/generic/d4[3][0]
#                                                                  0/0/generic/d4[4][0]
#                                                                  0/0/generic/d4[5][0]
#                                                                  0/0/generic/d4[6][0]
#                                                                  0/0/generic/d4[7][0]
#                                                                  0/0/generic/d4[8][0]
#                                                                  0/0/generic/d4[9][0]
# __________________________________________________________________________________________________
# 0/0/generic/backcast (Dense)    (None, 2016)         582624      0/0/generic/theta_b[0][0]
#                                                                  0/0/generic/theta_b[1][0]
#                                                                  0/0/generic/theta_b[2][0]
#                                                                  0/0/generic/theta_b[3][0]
#                                                                  0/0/generic/theta_b[4][0]
#                                                                  0/0/generic/theta_b[5][0]
#                                                                  0/0/generic/theta_b[6][0]
#                                                                  0/0/generic/theta_b[7][0]
#                                                                  0/0/generic/theta_b[8][0]
#                                                                  0/0/generic/theta_b[9][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 2016)         0           lambda_1[0][0]
#                                                                  0/0/generic/backcast[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 2016)         0           subtract_1[0][0]
#                                                                  0/0/generic/backcast[1][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 2016)         0           subtract_2[0][0]
#                                                                  0/0/generic/backcast[2][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 2016)         0           subtract_3[0][0]
#                                                                  0/0/generic/backcast[3][0]
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 2016)         0           subtract_4[0][0]
#                                                                  0/0/generic/backcast[4][0]
# __________________________________________________________________________________________________
# subtract_6 (Subtract)           (None, 2016)         0           subtract_5[0][0]
#                                                                  0/0/generic/backcast[5][0]
# __________________________________________________________________________________________________
# subtract_7 (Subtract)           (None, 2016)         0           subtract_6[0][0]
#                                                                  0/0/generic/backcast[6][0]
# __________________________________________________________________________________________________
# subtract_8 (Subtract)           (None, 2016)         0           subtract_7[0][0]
#                                                                  0/0/generic/backcast[7][0]
# __________________________________________________________________________________________________
# subtract_9 (Subtract)           (None, 2016)         0           subtract_8[0][0]
#                                                                  0/0/generic/backcast[8][0]
# __________________________________________________________________________________________________
# subtract_10 (Subtract)          (None, 2016)         0           subtract_9[0][0]
#                                                                  0/0/generic/backcast[9][0]
# __________________________________________________________________________________________________
# 1/0/generic/d1 (Dense)          (None, 100)          201700      subtract_10[0][0]
#                                                                  subtract_11[0][0]
#                                                                  subtract_12[0][0]
#                                                                  subtract_13[0][0]
#                                                                  subtract_14[0][0]
#                                                                  subtract_15[0][0]
#                                                                  subtract_16[0][0]
#                                                                  subtract_17[0][0]
#                                                                  subtract_18[0][0]
#                                                                  subtract_19[0][0]
# __________________________________________________________________________________________________
# 1/0/generic/d2 (Dense)          (None, 100)          10100       1/0/generic/d1[0][0]
#                                                                  1/0/generic/d1[1][0]
#                                                                  1/0/generic/d1[2][0]
#                                                                  1/0/generic/d1[3][0]
#                                                                  1/0/generic/d1[4][0]
#                                                                  1/0/generic/d1[5][0]
#                                                                  1/0/generic/d1[6][0]
#                                                                  1/0/generic/d1[7][0]
#                                                                  1/0/generic/d1[8][0]
#                                                                  1/0/generic/d1[9][0]
# __________________________________________________________________________________________________
# 1/0/generic/d3 (Dense)          (None, 100)          10100       1/0/generic/d2[0][0]
#                                                                  1/0/generic/d2[1][0]
#                                                                  1/0/generic/d2[2][0]
#                                                                  1/0/generic/d2[3][0]
#                                                                  1/0/generic/d2[4][0]
#                                                                  1/0/generic/d2[5][0]
#                                                                  1/0/generic/d2[6][0]
#                                                                  1/0/generic/d2[7][0]
#                                                                  1/0/generic/d2[8][0]
#                                                                  1/0/generic/d2[9][0]
# __________________________________________________________________________________________________
# 1/0/generic/d4 (Dense)          (None, 100)          10100       1/0/generic/d3[0][0]
#                                                                  1/0/generic/d3[1][0]
#                                                                  1/0/generic/d3[2][0]
#                                                                  1/0/generic/d3[3][0]
#                                                                  1/0/generic/d3[4][0]
#                                                                  1/0/generic/d3[5][0]
#                                                                  1/0/generic/d3[6][0]
#                                                                  1/0/generic/d3[7][0]
#                                                                  1/0/generic/d3[8][0]
#                                                                  1/0/generic/d3[9][0]
# __________________________________________________________________________________________________
# 1/0/generic/theta_b (Dense)     (None, 288)          28800       1/0/generic/d4[0][0]
#                                                                  1/0/generic/d4[1][0]
#                                                                  1/0/generic/d4[2][0]
#                                                                  1/0/generic/d4[3][0]
#                                                                  1/0/generic/d4[4][0]
#                                                                  1/0/generic/d4[5][0]
#                                                                  1/0/generic/d4[6][0]
#                                                                  1/0/generic/d4[7][0]
#                                                                  1/0/generic/d4[8][0]
# __________________________________________________________________________________________________
# 1/0/generic/backcast (Dense)    (None, 2016)         582624      1/0/generic/theta_b[0][0]
#                                                                  1/0/generic/theta_b[1][0]
#                                                                  1/0/generic/theta_b[2][0]
#                                                                  1/0/generic/theta_b[3][0]
#                                                                  1/0/generic/theta_b[4][0]
#                                                                  1/0/generic/theta_b[5][0]
#                                                                  1/0/generic/theta_b[6][0]
#                                                                  1/0/generic/theta_b[7][0]
#                                                                  1/0/generic/theta_b[8][0]
# __________________________________________________________________________________________________
# subtract_11 (Subtract)          (None, 2016)         0           subtract_10[0][0]
#                                                                  1/0/generic/backcast[0][0]
# __________________________________________________________________________________________________
# subtract_12 (Subtract)          (None, 2016)         0           subtract_11[0][0]
#                                                                  1/0/generic/backcast[1][0]
# __________________________________________________________________________________________________
# subtract_13 (Subtract)          (None, 2016)         0           subtract_12[0][0]
#                                                                  1/0/generic/backcast[2][0]
# __________________________________________________________________________________________________
# subtract_14 (Subtract)          (None, 2016)         0           subtract_13[0][0]
#                                                                  1/0/generic/backcast[3][0]
# __________________________________________________________________________________________________
# subtract_15 (Subtract)          (None, 2016)         0           subtract_14[0][0]
#                                                                  1/0/generic/backcast[4][0]
# __________________________________________________________________________________________________
# subtract_16 (Subtract)          (None, 2016)         0           subtract_15[0][0]
#                                                                  1/0/generic/backcast[5][0]
# __________________________________________________________________________________________________
# subtract_17 (Subtract)          (None, 2016)         0           subtract_16[0][0]
#                                                                  1/0/generic/backcast[6][0]
# __________________________________________________________________________________________________
# 0/0/generic/theta_f (Dense)     (None, 288)          28800       0/0/generic/d4[0][0]
#                                                                  0/0/generic/d4[1][0]
#                                                                  0/0/generic/d4[2][0]
#                                                                  0/0/generic/d4[3][0]
#                                                                  0/0/generic/d4[4][0]
#                                                                  0/0/generic/d4[5][0]
#                                                                  0/0/generic/d4[6][0]
#                                                                  0/0/generic/d4[7][0]
#                                                                  0/0/generic/d4[8][0]
#                                                                  0/0/generic/d4[9][0]
# __________________________________________________________________________________________________
# 0/0/generic/forecast (Dense)    (None, 288)          83232       0/0/generic/theta_f[0][0]
#                                                                  0/0/generic/theta_f[1][0]
#                                                                  0/0/generic/theta_f[2][0]
#                                                                  0/0/generic/theta_f[3][0]
#                                                                  0/0/generic/theta_f[4][0]
#                                                                  0/0/generic/theta_f[5][0]
#                                                                  0/0/generic/theta_f[6][0]
#                                                                  0/0/generic/theta_f[7][0]
#                                                                  0/0/generic/theta_f[8][0]
#                                                                  0/0/generic/theta_f[9][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 288)          0           0/0/generic/forecast[0][0]
#                                                                  0/0/generic/forecast[1][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 288)          0           add_1[0][0]
#                                                                  0/0/generic/forecast[2][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 288)          0           add_2[0][0]
#                                                                  0/0/generic/forecast[3][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 288)          0           add_3[0][0]
#                                                                  0/0/generic/forecast[4][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 288)          0           add_4[0][0]
#                                                                  0/0/generic/forecast[5][0]
# __________________________________________________________________________________________________
# subtract_18 (Subtract)          (None, 2016)         0           subtract_17[0][0]
#                                                                  1/0/generic/backcast[7][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 288)          0           add_5[0][0]
#                                                                  0/0/generic/forecast[6][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 288)          0           add_6[0][0]
#                                                                  0/0/generic/forecast[7][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 288)          0           add_7[0][0]
#                                                                  0/0/generic/forecast[8][0]
# __________________________________________________________________________________________________
# 1/0/generic/theta_f (Dense)     (None, 288)          28800       1/0/generic/d4[0][0]
#                                                                  1/0/generic/d4[1][0]
#                                                                  1/0/generic/d4[2][0]
#                                                                  1/0/generic/d4[3][0]
#                                                                  1/0/generic/d4[4][0]
#                                                                  1/0/generic/d4[5][0]
#                                                                  1/0/generic/d4[6][0]
#                                                                  1/0/generic/d4[7][0]
#                                                                  1/0/generic/d4[8][0]
#                                                                  1/0/generic/d4[9][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 288)          0           add_8[0][0]
#                                                                  0/0/generic/forecast[9][0]
# __________________________________________________________________________________________________
# 1/0/generic/forecast (Dense)    (None, 288)          83232       1/0/generic/theta_f[0][0]
#                                                                  1/0/generic/theta_f[1][0]
#                                                                  1/0/generic/theta_f[2][0]
#                                                                  1/0/generic/theta_f[3][0]
#                                                                  1/0/generic/theta_f[4][0]
#                                                                  1/0/generic/theta_f[5][0]
#                                                                  1/0/generic/theta_f[6][0]
#                                                                  1/0/generic/theta_f[7][0]
#                                                                  1/0/generic/theta_f[8][0]
#                                                                  1/0/generic/theta_f[9][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 288)          0           add_9[0][0]
#                                                                  1/0/generic/forecast[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 288)          0           add_10[0][0]
#                                                                  1/0/generic/forecast[1][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 288)          0           add_11[0][0]
#                                                                  1/0/generic/forecast[2][0]
# __________________________________________________________________________________________________
# subtract_19 (Subtract)          (None, 2016)         0           subtract_18[0][0]
#                                                                  1/0/generic/backcast[8][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 288)          0           add_12[0][0]
#                                                                  1/0/generic/forecast[3][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 288)          0           add_13[0][0]
#                                                                  1/0/generic/forecast[4][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 288)          0           add_14[0][0]
#                                                                  1/0/generic/forecast[5][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 288)          0           add_15[0][0]
#                                                                  1/0/generic/forecast[6][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 288)          0           add_16[0][0]
#                                                                  1/0/generic/forecast[7][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 288)          0           add_17[0][0]
#                                                                  1/0/generic/forecast[8][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 288)          0           add_18[0][0]
#                                                                  1/0/generic/forecast[9][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 288, 1)       0           add_19[0][0]
# ==================================================================================================
# Total params: 1,910,912
# Trainable params: 1,910,912
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size = args.batch_size, epochs = args.num_epochs, validation_data = (X_val, y_val), callbacks=[earlystop], verbose=1)
# Out:
# Train on 69697 samples, validate on 12097 samples
# Epoch 1/100
# 69697/69697 [==============================] - 6s 92us/step - loss: 0.0656 - val_loss: 0.0194
# Epoch 2/100
# 69697/69697 [==============================] - 5s 73us/step - loss: 0.0158 - val_loss: 0.0111
# Epoch 3/100
# 69697/69697 [==============================] - 5s 73us/step - loss: 0.0105 - val_loss: 0.0085
# Epoch 4/100
# 69697/69697 [==============================] - 5s 73us/step - loss: 0.0088 - val_loss: 0.0074
# Epoch 5/100
# 69697/69697 [==============================] - 5s 74us/step - loss: 0.0079 - val_loss: 0.0067
# Epoch 6/100
# 69697/69697 [==============================] - 5s 75us/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 7/100
# 69697/69697 [==============================] - 5s 75us/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 8/100
# 69697/69697 [==============================] - 5s 75us/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 9/100
# 69697/69697 [==============================] - 5s 76us/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 10/100
# 69697/69697 [==============================] - 5s 76us/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 11/100
# 69697/69697 [==============================] - 5s 75us/step - loss: 0.0055 - val_loss: 0.0057
# Epoch 12/100
# 69697/69697 [==============================] - 5s 75us/step - loss: 0.0053 - val_loss: 0.0055
# Epoch 13/100
# 69697/69697 [==============================] - 5s 75us/step - loss: 0.0051 - val_loss: 0.0055
# Epoch 14/100
# 69697/69697 [==============================] - 5s 75us/step - loss: 0.0049 - val_loss: 0.0052
# Epoch 15/100
# 69697/69697 [==============================] - 5s 74us/step - loss: 0.0048 - val_loss: 0.0056
# Epoch 16/100
# 69697/69697 [==============================] - 5s 75us/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 17/100
# 69697/69697 [==============================] - 5s 74us/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 18/100
# 69697/69697 [==============================] - 5s 74us/step - loss: 0.0043 - val_loss: 0.0053

# %%
best_epoch = np.argmin(np.array(history.history['val_loss']))+1
model.save_weights('forecasts/' + args.save_folder + '/model_{:02d}.h5'.format(best_epoch))
model.load_weights('forecasts/' + args.save_folder + '/model_{:02d}.h5'.format(best_epoch))
best_epoch
# Out:
# 16

# %%
#24

# %%
plot_df = po.DataFrame.from_dict({'train_loss':history.history['loss'], 'val_loss':history.history['val_loss']})
plot_df.plot(logy=True, figsize=(10,10), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.savefig('forecasts/' + args.save_folder + '/train_val_loss.png')
plt.show()

# %%
y_pred = model.predict(X_test)

# %%
y_pred = y_pred.squeeze()
y_test = y_test.squeeze()

# %%
plt.plot(y_test[0], color = 'blue')
plt.plot(y_pred[0], color = 'red')
plt.savefig('forecasts/' + args.save_folder + '/test_1_pred.png')

# %%
plt.plot(y_test[12*24*2], color = 'blue')
plt.plot(y_pred[12*24*2], color = 'red')
plt.savefig('forecasts/' + args.save_folder + '/test_2_pred.png')

# %%
forecasts = []
actuals = []
forecasts_n = []
actuals_n = []
for i in tqdm(range(y_pred.shape[0]//288)): ## we have forecasts for these many complete day
  forecasts += (scaler.inverse_transform(y_pred[12*24*i].reshape(-1, 1)).reshape(-1)).tolist()
  actuals += (scaler.inverse_transform(y_test[12*24*i].reshape(-1, 1)).reshape(-1)).tolist()
  forecasts_n += y_pred[12*24*i].tolist()
  actuals_n += y_test[12*24*i].tolist()
# Out:
# 100%|██████████| 42/42 [00:00<00:00, 4716.36it/s]

# %%
df_pred = po.DataFrame()
df_pred['Predictions'] = forecasts
df_pred['Actual Values'] = actuals

# %%
df_pred.to_csv('forecasts/' + args.save_folder + '/full_results.csv', index = False)

# %%
df_pred_n = po.DataFrame()
df_pred_n['Predictions'] = forecasts_n
df_pred_n['Actual Values'] = actuals_n

# %%
df_pred_n.to_csv('forecasts/' + args.save_folder + '/full_results_normalized.csv', index = False)

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Days', size = 20)
plt.ylabel('Energy Comsumption (kWh)', size = 20)
plt.xticks(ticks = list(range(0, len(forecasts) + 1, 288)), labels = list(range(0, int(len(forecasts)/288 + 1))), size = 10)
plt.yticks(size = 10)
plt.plot(actuals, color = 'blue')
plt.plot(forecasts, color = 'red')
plt.legend(['Actual Value', 'Prediction'])
plt.savefig('forecasts/' + args.save_folder + '/forecast.png')

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Days', size = 20)
plt.ylabel('Energy Comsumption (kWh)', size = 20)
plt.xticks(ticks = list(range(0, len(forecasts) + 1, 288)), labels = list(range(0, int(len(forecasts)/288 + 1))), size = 10)
plt.yticks(size = 10)
plt.plot(actuals_n, color = 'blue')
plt.plot(forecasts_n, color = 'red')
plt.legend(['Actual Value', 'Prediction'])
plt.savefig('forecasts/' + args.save_folder + '/forecast_normalized.png')

# %%
if not os.path.exists('forecasts/results.csv'):
  results = po.DataFrame(columns = ['model', 'MAE', 'MSE', 'R2'])  
else:
  results = po.read_csv('forecasts/results.csv')

# %%
errors = {'model': args.save_folder,
          'MAE': mean_absolute_error(y_true=y_test, y_pred=y_pred),
          'MAPE': mean_absolute_error(y_true=y_test, y_pred=y_pred)*100,
          'MSE': mean_squared_error(y_true=y_test, y_pred=y_pred),
          'RMSE': mean_squared_error(y_true=y_test, y_pred=y_pred, squared=False),
          'R2': r2_score(y_true=y_test, y_pred=y_pred)          
          }
errors = po.Series(errors)
results = results.append(errors, ignore_index=True)

# %%
results
# Out:
#                            model       MAE  ...      MAPE      RMSE
# 0                       CNN_LSTM  0.048751  ...  4.875098  0.063956
# 1                    Dilated_CNN  0.049959  ...  4.995887  0.062528
# 2                       convLSTM  0.045311  ...  4.531112  0.058987
# 3   weekend_forecast_Dilated_CNN  0.044546  ...  4.454638  0.053893
# 4      weekend_forecast_CNN_LSTM  0.040486  ...  4.048602  0.050856
# 5     weekend_forecast_conv_LSTM  0.038764  ...  3.876431  0.049156
# 6       weekend_forecast_WaveNet  0.047001  ...  4.700087  0.056060
# 7                        WaveNet  0.038622  ...  3.862250  0.052177
# 8   weekday_forecast_Dilated_CNN  0.057209  ...  5.720929  0.072542
# 9      weekday_forecast_CNN_LSTM  0.039897  ...  3.989721  0.052985
# 10    weekday_forecast_conv_LSTM  0.039710  ...  3.971010  0.052723
# 11      weekday_forecast_WaveNet  0.046508  ...  4.650779  0.060408
# 12       weekday_forecast_NBEATS  0.041976  ...  4.197626  0.054749
# 13       weekend_forecast_NBEATS  0.037998  ...  3.799763  0.050593
# 14       weekday_forecast_NBEATS  0.037855  ...  3.785495  0.050929
# 15                        NBEATS  0.035991  ...  3.599133  0.049077
#
# [16 rows x 6 columns]

# %%
results.to_csv('forecasts/results.csv', index=False)
