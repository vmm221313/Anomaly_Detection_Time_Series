# %%
import random
import argparse
import numpy as np
import pandas as po
from tqdm import tqdm
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
# set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# %%
df = po.read_csv('final_data/univariate.csv')
df
# Out:
#          consumption
# 0      126661.288667
# 1      125975.630600
# 2      131628.821400
# 3      133741.109667
# 4      149806.386667
# ...              ...
# 99643  103932.504002
# 99644  102064.379714
# 99645  100378.796042
# 99646   98593.460339
# 99647   97365.874939
#
# [99648 rows x 1 columns]

# %%
scaler = MinMaxScaler()
df = po.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
train_df = df[:int(0.6*len(df))]
val_df = df[int(0.6*len(df)): int(0.8*len(df))]
test_df = df[int(0.8*len(df)):]

# %%
len(train_df), len(val_df), len(test_df)
# Out:
# (59788, 19930, 19930)

# %%
plt.figure(figsize=(20, 10))
plt.plot(train_df['consumption'], color='blue')
plt.plot(val_df['consumption'], color='orange')
plt.plot(test_df['consumption'], color='red')
plt.legend(['Train Sequence', 'Validation Sequence', 'Test Sequence'])

# %%
train_df = train_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)

# %%
lookback=4*24*14
horizon=4*24*1

# %%
def make_windows(data, target_col='consumption', lookback=4*24*14, horizon=4*24*1):
    
    X = np.zeros((len(data)-lookback - horizon + 1, lookback, len(data.columns)))
    y = np.zeros((len(data)-lookback - horizon + 1, horizon, 1))

    for i in tqdm(range(lookback, len(data) - horizon + 1)):  
        X[i-lookback, :, :] = data.iloc[i - lookback: i].values
        y[i-lookback, :, :] = data.iloc[i: i + horizon][target_col].values.reshape(-1, 1)

    return X, y

# %%
X_train, y_train = make_windows(train_df)
# Out:
# 100%|██████████| 58349/58349 [00:09<00:00, 6398.40it/s]

# %%
X_val, y_val = make_windows(val_df)
# Out:
# 100%|██████████| 18491/18491 [00:02<00:00, 6370.95it/s]

# %%
X_test, y_test = make_windows(test_df)
# Out:
# 100%|██████████| 18491/18491 [00:02<00:00, 6440.67it/s]

# %%
sgd = tf.keras.optimizers.SGD(lr=1e-2, decay=1e-8, momentum=0.9, nesterov=True)
earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00001, patience=10)
loss_funk = tf.keras.losses.MeanSquaredError(reduction='sum_over_batch_size')

# %%
batch_size = 256
num_epochs = 100

# %%
X_train.shape
# Out:
# (58349, 1344, 1)

# %%
X_train = X_train.reshape(-1, 1, lookback, 1)
y_train = y_train.squeeze()
X_val = X_val.reshape(-1, 1, lookback, 1)
y_val = y_val.squeeze()
X_test = X_test.reshape(-1, 1, lookback, 1)
y_test = y_test.squeeze()

# %%
i = tf.keras.layers.Input((1, lookback, 1))
x = tf.keras.layers.TimeDistributed(tf.keras.layers.Conv1D(filters = 24, kernel_size = 4, activation = 'relu'))(i)
x = tf.keras.layers.TimeDistributed(tf.keras.layers.Conv1D(filters = 24, kernel_size = 4, activation = 'relu'))(x)
x = tf.keras.layers.TimeDistributed(tf.keras.layers.Flatten())(x)
x = tf.keras.layers.LSTM(50, activation = 'relu')(x)
x = tf.keras.layers.Dense(horizon)(x)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
model = tf.keras.models.Model(inputs=i, outputs=x)
model.compile(optimizer = sgd, loss = loss_funk)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1, 1344, 1)]      0
# _________________________________________________________________
# time_distributed (TimeDistri (None, 1, 1341, 24)       120
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 1, 1338, 24)       2328
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 1, 32112)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 50)                6432600
# _________________________________________________________________
# dense (Dense)                (None, 96)                4896
# =================================================================
# Total params: 6,439,944
# Trainable params: 6,439,944
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size = batch_size, epochs = num_epochs, validation_data = (X_val, y_val), callbacks=[earlystop], verbose=1)
# Out:
# Epoch 1/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0508 - val_loss: 0.0129
# Epoch 2/100
# 228/228 [==============================] - 4s 15ms/step - loss: 0.0160 - val_loss: 0.0124
# Epoch 3/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0151 - val_loss: 0.0119
# Epoch 4/100
# 228/228 [==============================] - 4s 15ms/step - loss: 0.0144 - val_loss: 0.0116
# Epoch 5/100
# 228/228 [==============================] - 4s 15ms/step - loss: 0.0137 - val_loss: 0.0112
# Epoch 6/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0130 - val_loss: 0.0109
# Epoch 7/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0124 - val_loss: 0.0104
# Epoch 8/100
# 228/228 [==============================] - 4s 15ms/step - loss: 0.0117 - val_loss: 0.0100
# Epoch 9/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0111 - val_loss: 0.0097
# Epoch 10/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0105 - val_loss: 0.0093
# Epoch 11/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0100 - val_loss: 0.0091
# Epoch 12/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0095 - val_loss: 0.0088
# Epoch 13/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 14/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0089 - val_loss: 0.0084
# Epoch 15/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0087 - val_loss: 0.0083
# Epoch 16/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0085 - val_loss: 0.0082
# Epoch 17/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0083 - val_loss: 0.0081
# Epoch 18/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0082 - val_loss: 0.0079
# Epoch 19/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 20/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 21/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 22/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 23/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 24/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0078 - val_loss: 0.0077
# Epoch 25/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 26/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 27/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 28/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 29/100
# 228/228 [==============================] - 4s 15ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 30/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 31/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 32/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 33/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 34/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 35/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 36/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 37/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 38/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 39/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 40/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0075 - val_loss: 0.0074
# Epoch 41/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 42/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 43/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 44/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 45/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 46/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0074 - val_loss: 0.0074
# Epoch 47/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 48/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 49/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 50/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 51/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 52/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 53/100
# 228/228 [==============================] - 4s 15ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 54/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 55/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 56/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 57/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 58/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 59/100
# 228/228 [==============================] - 4s 15ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 60/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 61/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 62/100
# 228/228 [==============================] - 4s 15ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 63/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 64/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0071 - val_loss: 0.0072
# Epoch 65/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 66/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 67/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 68/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 69/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 70/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 71/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0070 - val_loss: 0.0072
# Epoch 72/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 73/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 74/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 75/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 76/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0069 - val_loss: 0.0071
# Epoch 77/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 78/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 79/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0068 - val_loss: 0.0071
# Epoch 80/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0068 - val_loss: 0.0072
# Epoch 81/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0068 - val_loss: 0.0071
# Epoch 82/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0068 - val_loss: 0.0071
# Epoch 83/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0068 - val_loss: 0.0071
# Epoch 84/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0067 - val_loss: 0.0072
# Epoch 85/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 86/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 87/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 88/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 89/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 90/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 91/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 92/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0066 - val_loss: 0.0071
# Epoch 93/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 94/100
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 95/100
# 228/228 [==============================] - 3s 14ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 96/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0066 - val_loss: 0.0070
# Epoch 97/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 98/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 99/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0065 - val_loss: 0.0070
# Epoch 100/100
# 228/228 [==============================] - 3s 15ms/step - loss: 0.0065 - val_loss: 0.0070

# %%
model.save('saved_models/cnn_lstm_univariate.hdf5')

# %%
#model = tf.keras.models.load_model('saved_models/nbeats_univ.hdf5')

# %%
plot_df = po.DataFrame.from_dict({'train_loss':history.history['loss'], 'val_loss':history.history['val_loss']})
plot_df.plot(logy=True, figsize=(10,10), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
#plt.savefig('forecasts/' + args.save_folder + '/train_val_loss.png')
plt.show()

# %%
y_pred = model.predict(X_test)

# %%
y_pred = y_pred.squeeze()
y_test = y_test.squeeze()

# %%
plt.plot(y_test[5251], color = 'blue')
plt.plot(y_pred[5251], color = 'red')
#plt.savefig('forecasts/' + args.save_folder + '/test_1_pred.png')

# %%
forecasts = []
actuals = []
forecasts_n = []
actuals_n = []
for i in tqdm(range(y_pred.shape[0]//288)): ## we have forecasts for these many complete day
  forecasts += (scaler.inverse_transform(y_pred[12*24*i].reshape(-1, 1)).reshape(-1)).tolist()
  actuals += (scaler.inverse_transform(y_test[12*24*i].reshape(-1, 1)).reshape(-1)).tolist()
  forecasts_n += y_pred[12*24*i].tolist()
  actuals_n += y_test[12*24*i].tolist()
# Out:
# 100%|██████████| 64/64 [00:00<00:00, 7773.98it/s]

# %%
df_pred = po.DataFrame()
df_pred['Predictions'] = forecasts
df_pred['Actual Values'] = actuals

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Days', size = 20)
plt.ylabel('Energy Comsumption (kWh)', size = 20)
plt.xticks(ticks = list(range(0, len(forecasts) + 1, 288)), labels = list(range(0, int(len(forecasts)/288 + 1))), size = 10)
plt.yticks(size = 10)
plt.plot(actuals, color = 'blue')
plt.plot(forecasts, color = 'red')
plt.legend(['Actual Value', 'Prediction'])

# %%
plt.figure(figsize=(20, 10))
plt.xlabel('Days', size = 20)
plt.ylabel('Energy Comsumption (kWh)', size = 20)
plt.xticks(ticks = list(range(0, len(forecasts) + 1, 288)), labels = list(range(0, int(len(forecasts)/288 + 1))), size = 10)
plt.yticks(size = 10)
plt.plot(actuals_n, color = 'blue')
plt.plot(forecasts_n, color = 'red')
plt.legend(['Actual Value', 'Prediction'])

# %%
results = po.DataFrame(columns = ['MAE', 'MSE', 'R2'])  
errors = {'MAE': mean_absolute_error(y_true=y_test, y_pred=y_pred),
          'MAPE': mean_absolute_error(y_true=y_test, y_pred=y_pred)*100,
          'MSE': mean_squared_error(y_true=y_test, y_pred=y_pred),
          'RMSE': mean_squared_error(y_true=y_test, y_pred=y_pred, squared=False),
          'R2': r2_score(y_true=y_test, y_pred=y_pred)          
          }
errors = po.Series(errors)
results = results.append(errors, ignore_index=True)
results
# Out:
#         MAE       MSE        R2      MAPE      RMSE
# 0  0.067013  0.009278  0.468267  6.701268  0.096324
